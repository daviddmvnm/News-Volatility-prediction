# %% [markdown]
# ### Time Aggregation:
#
# - Take our thematicaly tagged gold delta, and aggregate by time to create sentiment and activity features by theme

# %%
from pathlib import Path
from pyspark.sql import SparkSession
from delta import configure_spark_with_delta_pip

#paths
NB_DIR = Path.cwd()
ROOT = NB_DIR.parent
GOLD_DELTA = ROOT / "pipelines" / "gold" / "gold_delta"
THEMATIC_DELTA = ROOT / "clustering" / "thematic_clusters"   
print("Thematic Cluster Delta:", THEMATIC_DELTA)

#spark
builder = (
    SparkSession.builder
        .appName("time_agg")
        .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
        .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
        .config("spark.driver.memory", "10g")
        .config("spark.sql.shuffle.partitions", "16")
)

spark = configure_spark_with_delta_pip(builder).getOrCreate()



#load
df_gold = spark.read.format("delta").load(str(GOLD_DELTA))
df_theme = spark.read.format("delta").load(str(THEMATIC_DELTA))

#Remove old macro column if present
if "macro_cluster" in df_gold.columns:
    df_gold = df_gold.drop("macro_cluster")

df = df_gold.join(df_theme, on="url", how="inner")
df.show(5, truncate=False)
print("Joined rows:", df.count())
# Out:
# Thematic Cluster Delta: /home/david/School/CapStone/clustering/thematic_clusters
# 25/12/08 18:34:41 WARN Utils: Your hostname, david-ThinkPad-T490 resolves to a loopback address: 127.0.1.1; using 172.16.0.186 instead (on interface wlp0s20f3)
# 25/12/08 18:34:41 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/david/School/CapStone/.venv/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/david/.ivy2/cache
# The jars for the packages stored in: /home/david/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-499c51b0-2368-4121-954d-f680efb359c0;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.1.0 in central
# 	found io.delta#delta-storage;3.1.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# :: resolution report :: resolve 359ms :: artifacts dl 13ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.1.0 from central in [default]
# 	io.delta#delta-storage;3.1.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-499c51b0-2368-4121-954d-f680efb359c0
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/11ms)
# 25/12/08 18:34:42 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/08 18:34:55 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# 25/12/08 18:35:03 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +------------------------------------------------------------------------------------------------------------+-------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+---------------+----------------+--------------+------------+----------------+--------------+---------------------------------------+-----------------------+-----------------------------------------------------------------------------------+--------+-----------------------+------------+------------+------------+------------+------------+-------------+------------+-------------+------------+------------+------------+------------+-----------+------------+------------+------------+-----------+-------------+------------+------------+------------+------------+-----------+------------+------------+-------------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+-----------+------------+------------+-------------+------------+------------+-----------+-------------+------------+------------+------------+------------+------------+------------+------------+-------------+-----------+-----------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+------------+-----------+-----------+------------+------------+------------+------------+------------+-------------+------------+-----------+------------+------------+------------+-------------+------------+-------------+-------------+-------------+------------+------------+-----------+------------+-------------+-----------+-------------+------------+------------+------------+-----------+------------+------------+------------+------------+------------+-----------+-----------+------------+---------- ...
# |url                                                                                                         |date               |text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |publication       |author         |text_type       |time_precision|date_trading|tz_hint         |dataset       |dataset_source                         |source                 |source_file                                                                        |len_text|silver_ingestion_ts    |emb_0       |emb_1       |emb_2       |emb_3       |emb_4       |emb_5        |emb_6       |emb_7        |emb_8       |emb_9       |emb_10      |emb_11      |emb_12     |emb_13      |emb_14      |emb_15      |emb_16     |emb_17       |emb_18      |emb_19      |emb_20      |emb_21      |emb_22     |emb_23      |emb_24      |emb_25       |emb_26     |emb_27      |emb_28      |emb_29      |emb_30      |emb_31      |emb_32      |emb_33      |emb_34      |emb_35     |emb_36      |emb_37      |emb_38       |emb_39      |emb_40      |emb_41     |emb_42       |emb_43      |emb_44      |emb_45      |emb_46      |emb_47      |emb_48      |emb_49      |emb_50       |emb_51     |emb_52     |emb_53      |emb_54      |emb_55      |emb_56       |emb_57      |emb_58      |emb_59      |emb_60      |emb_61      |emb_62      |emb_63      |emb_64      |emb_65      |emb_66      |emb_67      |emb_68      |emb_69       |emb_70      |emb_71     |emb_72     |emb_73      |emb_74      |emb_75      |emb_76      |emb_77      |emb_78       |emb_79      |emb_80     |emb_81      |emb_82      |emb_83      |emb_84       |emb_85      |emb_86       |emb_87       |emb_88       |emb_89      |emb_90      |emb_91     |emb_92      |emb_93       |emb_94     |emb_95       |emb_96      |emb_97      |emb_98      |emb_99     |emb_100     |emb_101     |emb_102     |emb_103     |emb_104     |emb_105    |emb_106    |emb_107     |emb_108    ...
# +------------------------------------------------------------------------------------------------------------+-------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+---------------+----------------+--------------+------------+----------------+--------------+---------------------------------------+-----------------------+-----------------------------------------------------------------------------------+--------+-----------------------+------------+------------+------------+------------+------------+-------------+------------+-------------+------------+------------+------------+------------+-----------+------------+------------+------------+-----------+-------------+------------+------------+------------+------------+-----------+------------+------------+-------------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+-----------+------------+------------+-------------+------------+------------+-----------+-------------+------------+------------+------------+------------+------------+------------+------------+-------------+-----------+-----------+------------+------------+------------+-------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+------------+-----------+-----------+------------+------------+------------+------------+------------+-------------+------------+-----------+------------+------------+------------+-------------+------------+-------------+-------------+-------------+------------+------------+-----------+------------+-------------+-----------+-------------+------------+------------+------------+-----------+------------+------------+------------+------------+------------+-----------+-----------+------------+---------- ...
# |http://artsbeat.blogs.nytimes.com/2016/01/05/gerard-and-kelly-to-perform-at-schindler-house-and-glass-house/|2016-01-05 00:00:00|Gerard and Kelly to Perform at Schindler House and Glass House\n\nArchitecture and performance art have gone together at least since Yves Klein’s “Leap Into the Void,” his 1960 photomontage that makes it look as if he is swan-diving from the ledge of an elegant mansard roof. Beginning this weekend, the dancers and visual artists Brennan Gerard and Ryan Kelly will use two of the country’s most beloved 20th-century houses – the Schindler House, designed by Rudolph M. Schindler in West Hollywood, Calif., and the Glass House, Philip Johnson’s masterpiece in New Canaan, Conn. – as walk-in texts for a performance work focusing on what they describe as “themes of queer intimacy and domestic space within the legacies of modernist architecture.” The performances, which will begin Saturday and Sunday at the Schindler House in collaboration with Benjamin Millepied’s L.A. Dance Project, will come to the Glass House in May. The piece, “Modern Living,” will mark the first artistic collaboration between
------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+------------+-----------+-----------+------------+------------+------------+------------+------------+-------------+------------+-----------+------------+------------+------------+-------------+------------+-------------+-------------+-------------+------------+------------+-----------+------------+-------------+-----------+-------------+------------+------------+------------+-----------+------------+------------+------------+------------+------------+-----------+-----------+------------+---------- ...
# only showing top 5 rows
# [Stage 22:===================================================>    (11 + 1) / 12]
# Joined rows: 1949081

# %%
df.printSchema()

from pyspark.sql.functions import min as Fmin, max as Fmax, to_date

# Convert timestamp → date if not already
df_dates = df.withColumn("date_key", to_date("date"))

date_range = (
    df_dates
        .agg(
            Fmin("date_key").alias("start_date"),
            Fmax("date_key").alias("end_date")
        )
        .collect()[0]
)

print("Start date:", date_range["start_date"])
print("End date:", date_range["end_date"])
# Out:
# root
#  |-- url: string (nullable = true)
#  |-- date: timestamp_ntz (nullable = true)
#  |-- text: string (nullable = true)
#  |-- publication: string (nullable = true)
#  |-- author: string (nullable = true)
#  |-- text_type: string (nullable = true)
#  |-- time_precision: string (nullable = true)
#  |-- date_trading: timestamp_ntz (nullable = true)
#  |-- tz_hint: string (nullable = true)
#  |-- dataset: string (nullable = true)
#  |-- dataset_source: string (nullable = true)
#  |-- source: string (nullable = true)
#  |-- source_file: string (nullable = true)
#  |-- len_text: integer (nullable = true)
#  |-- silver_ingestion_ts: timestamp_ntz (nullable = true)
#  |-- emb_0: float (nullable = true)
#  |-- emb_1: float (nullable = true)
#  |-- emb_2: float (nullable = true)
#  |-- emb_3: float (nullable = true)
#  |-- emb_4: float (nullable = true)
#  |-- emb_5: float (nullable = true)
#  |-- emb_6: float (nullable = true)
#  |-- emb_7: float (nullable = true)
#  |-- emb_8: float (nullable = true)
#  |-- emb_9: float (nullable = true)
#  |-- emb_10: float (nullable = true)
#  |-- emb_11: float (nullable = true)
#  |-- emb_12: float (nullable = true)
#  |-- emb_13: float (nullable = true)
#  |-- emb_14: float (nullable = true)
#  |-- emb_15: float (nullable = true)
#  |-- emb_16: float (nullable = true)
#  |-- emb_17: float (nullable = true)
#  |-- emb_18: float (nullable = true)
#  |-- emb_19: float (nullable = true)
#  |-- emb_20: float (nullable = true)
#  |-- emb_21: float (nullable = true)
#  |-- emb_22: float (nullable = true)
#  |-- emb_23: float (nullable = true)
#  |-- emb_24: float (nullable = true)
#  |-- emb_25: float (nullable = true)
#  |-- emb_26: float (nullable = true)
#  |-- emb_27: float (nullable = true)
#  |-- emb_28: float (nullable = true)
#  |-- emb_29: float (nullable = true)
#  |-- emb_30: float (nullable = true)
#  |-- emb_31: float (nullable = true)
#  |-- emb_32: float (nullable = true)
#  |-- emb_33: float (nullable = true)
#  |-- emb_34: float (nullable = true)
#  |-- emb_35: float (nullable = true)
#  |-- emb_36: float (nullable = true)
#  |-- emb_37: float (nullable = true)
#  |-- emb_38: float (nullable = true)
#  |-- emb_39: float (nullable = true)
#  |-- emb_40: float (nullable = true)
#  |-- emb_41: float (nullable = true)
#  |-- emb_42: float (nullable = true)
#  |-- emb_43: float (nullable = true)
#  |-- emb_44: float (nullable = true)
#  |-- emb_45: float (nullable = true)
#  |-- emb_46: float (nullable = true)
#  |-- emb_47: float (nullable = true)
#  |-- emb_48: float (nullable = true)
#  |-- emb_49: float (nullable = true)
#  |-- emb_50: float (nullable = true)
#  |-- emb_51: float (nullable = true)
#  |-- emb_52: float (nullable = true)
#  |-- emb_53: float (nullable = true)
#  |-- emb_54: float (nullable = true)
#  |-- emb_55: float (nullable = true)
#  |-- emb_56: float (nullable = true)
#  |-- emb_57: float (nullable = true)
#  |-- emb_58: float (nullable = true)
#  |-- emb_59: float (nullable = true)
#  |-- emb_60: float (nullable = true)
#  |-- emb_61: float (nullable = true)
#  |-- emb_62: float (nullable = true)
#  |-- emb_63: float (nullable = true)
#  |-- emb_64: float (nullable = true)
#  |-- emb_65: float (nullable = true)
#  |-- emb_66: float (nullable = true)
#  |-- emb_67: float (nullable = true)
#  |-- emb_68: float (nullable = true)
#  |-- emb_69: float (nullable = true)
#  |-- emb_70: float (nullable = true)
#  |-- emb_71: float (nullable = true)
#  |-- emb_72: float (nullable = true)
#  |-- emb_73: float (nullable = true)
#  |-- emb_74: float (nullable = true)
#  |-- emb_75: float (nullable = true)
#  |-- emb_76: float (nullable = true)
#  |-- emb_77: float (nullable = true)
#  |-- emb_78: float (nullable = true)
#  |-- emb_79: float (nullable = true)
#  |-- emb_80: float (nullable = true)
#  |-- emb_81: float (nullable = true)
#  |-- emb_82: float (nullable = true)
#  |-- emb_83: float (nullable = true)
#  |-- emb_84: float (nullable = true)
#  |-- emb_85: float (nullable = true)
#  |-- emb_86: float (nullable = true)
#  |-- emb_87: float (nullable = true)
#  |-- emb_88: float (nullable = true)
#  |-- emb_89: float (nullable = true)
#  |-- emb_90: float (nullable = true)
#  |-- emb_91: float (nullable = true)
#  |-- emb_92: float (nullable = true)
#  |-- emb_93: float (nullable = true)
#  |-- emb_94: float (nullable = true)
#  |-- emb_95: float (nullable = true)
#  |-- emb_96: float (nullable = true)
#  |-- emb_97: float (nullable = true)
#  |-- emb_98: float (nullable = true)
#  |-- emb_99: float (nullable = true)
#  |-- emb_100: float (nullable = true)
#  |-- emb_101: float (nullable = true)
#  |-- emb_102: float (nullable = true)
#  |-- emb_103: float (nullable = true)
#  |-- emb_104: float (nullable = true)
#  |-- emb_105: float (nullable = true)
#  |-- emb_106: float (nullable = true)
#  |-- emb_107: float (nullable = true)
#  |-- emb_108: float (nullable = true)
#  |-- emb_109: float (nullable = true)
#  |-- emb_110: float (nullable = true)
#  |-- emb_111: float (nullable = true)
#  |-- emb_112: float (nullable = true)
#  |-- emb_113: float (nullable = true)
#  |-- emb_114: float (nullable = true)
#  |-- emb_115: float (nullable = true)
#  |-- emb_116: float (nullable = true)
#  |-- emb_117: float (nullable = true)
#  |-- emb_118: float (nullable = true)
#  |-- emb_119: float (nullable = true)
#  |-- emb_120: float (nullable = true)
#  |-- emb_121: float (nullable = true)
#  |-- emb_122: float (nullable = true)
#  |-- emb_123: float (nullable = true)
#  |-- emb_124: float (nullable = true)
#  |-- emb_125: float (nullable = true)
#  |-- emb_126: float (nullable = true)
#  |-- emb_127: float (nullable = true)
#  |-- emb_128: float (nullable = true)
#  |-- emb_129: float (nullable = true)
#  |-- emb_130: float (nullable = true)
#  |-- emb_131: float (nullable = true)
#  |-- emb_132: float (nullable = true)
#  |-- emb_133: float (nullable = true)
#  |-- emb_134: float (nullable = true)
#  |-- emb_135: float (nullable = true)
#  |-- emb_136: float (nullable = true)
#  |-- emb_137: float (nullable = true)
#  |-- emb_138: float (nullable = true)
#  |-- emb_139: float (nullable = true)
#  |-- emb_140: float (nullable = true)
#  |-- emb_141: float (nullable = true)
#  |-- emb_142: float (nullable = true)
#  |-- emb_143: float (nullable = true)
#  |-- emb_144: float (nullable = true)
#  |-- emb_145: float (nullable = true)
#  |-- emb_146: float (nullable = true)
#  |-- emb_147: float (nullable = true)
#  |-- emb_148: float (nullable = true)
#  |-- emb_149: float (nullable = true)
#  |-- emb_150: float (nullable = true)
#  |-- emb_151: float (nullable = true)
#  |-- emb_152: float (nullable = true)
#  |-- emb_153: float (nullable = true)
#  |-- emb_154: float (nullable = true)
#  |-- emb_155: float (nullable = true)
#  |-- emb_156: float (nullable = true)
#  |-- emb_157: float (nullable = true)
#  |-- emb_158: float (nullable = true)
#  |-- emb_159: float (nullable = true)
#  |-- emb_160: float (nullable = true)
#  |-- emb_161: float (nullable = true)
#  |-- emb_162: float (nullable = true)
#  |-- emb_163: float (nullable = true)
#  |-- emb_164: float (nullable = true)
#  |-- emb_165: float (nullable = true)
#  |-- emb_166: float (nullable = true)
#  |-- emb_167: float (nullable = true)
#  |-- emb_168: float (nullable = true)
#  |-- emb_169: float (nullable = true)
#  |-- emb_170: float (nullable = true)
#  |-- emb_171: float (nullable = true)
#  |-- emb_172: float (nullable = true)
#  |-- emb_173: float (nullable = true)
#  |-- emb_174: float (nullable = true)
#  |-- emb_175: float (nullable = true)
#  |-- emb_176: float (nullable = true)
#  |-- emb_177: float (nullable = true)
#  |-- emb_178: float (nullable = true)
#  |-- emb_179: float (nullable = true)
#  |-- emb_180: float (nullable = true)
#  |-- emb_181: float (nullable = true)
#  |-- emb_182: float (nullable = true)
#  |-- emb_183: float (nullable = true)
#  |-- emb_184: float (nullable = true)
#  |-- emb_185: float (nullable = true)
#  |-- emb_186: float (nullable = true)
#  |-- emb_187: float (nullable = true)
#  |-- emb_188: float (nullable = true)
#  |-- emb_189: float (nullable = true)
#  |-- emb_190: float (nullable = true)
#  |-- emb_191: float (nullable = true)
#  |-- emb_192: float (nullable = true)
#  |-- emb_193: float (nullable = true)
#  |-- emb_194: float (nullable = true)
#  |-- emb_195: float (nullable = true)
#  |-- emb_196: float (nullable = true)
#  |-- emb_197: float (nullable = true)
#  |-- emb_198: float (nullable = true)
#  |-- emb_199: float (nullable = true)
#  |-- emb_200: float (nullable = true)
#  |-- emb_201: float (nullable = true)
#  |-- emb_202: float (nullable = true)
#  |-- emb_203: float (nullable = true)
#  |-- emb_204: float (nullable = true)
#  |-- emb_205: float (nullable = true)
#  |-- emb_206: float (nullable = true)
#  |-- emb_207: float (nullable = true)
#  |-- emb_208: float (nullable = true)
#  |-- emb_209: float (nullable = true)
#  |-- emb_210: float (nullable = true)
#  |-- emb_211: float (nullable = true)
#  |-- emb_212: float (nullable = true)
#  |-- emb_213: float (nullable = true)
#  |-- emb_214: float (nullable = true)
#  |-- emb_215: float (nullable = true)
#  |-- emb_216: float (nullable = true)
#  |-- emb_217: float (nullable = true)
#  |-- emb_218: float (nullable = true)
#  |-- emb_219: float (nullable = true)
#  |-- emb_220: float (nullable = true)
#  |-- emb_221: float (nullable = true)
#  |-- emb_222: float (nullable = true)
#  |-- emb_223: float (nullable = true)
#  |-- emb_224: float (nullable = true)
#  |-- emb_225: float (nullable = true)
#  |-- emb_226: float (nullable = true)
#  |-- emb_227: float (nullable = true)
#  |-- emb_228: float (nullable = true)
#  |-- emb_229: float (nullable = true)
#  |-- emb_230: float (nullable = true)
#  |-- emb_231: float (nullable = true)
#  |-- emb_232: float (nullable = true)
#  |-- emb_233: float (nullable = true)
#  |-- emb_234: float (nullable = true)
#  |-- emb_235: float (nullable = true)
#  |-- emb_236: float (nullable = true)
#  |-- emb_237: float (nullable = true)
#  |-- emb_238: float (nullable = true)
#  |-- emb_239: float (nullable = true)
#  |-- emb_240: float (nullable = true)
#  |-- emb_241: float (nullable = true)
#  |-- emb_242: float (nullable = true)
#  |-- emb_243: float (nullable = true)
#  |-- emb_244: float (nullable = true)
#  |-- emb_245: float (nullable = true)
#  |-- emb_246: float (nullable = true)
#  |-- emb_247: float (nullable = true)
#  |-- emb_248: float (nullable = true)
#  |-- emb_249: float (nullable = true)
#  |-- emb_250: float (nullable = true)
#  |-- emb_251: float (nullable = true)
#  |-- emb_252: float (nullable = true)
#  |-- emb_253: float (nullable = true)
#  |-- emb_254: float (nullable = true)
#  |-- emb_255: float (nullable = true)
#  |-- emb_256: float (nullable = true)
#  |-- emb_257: float (nullable = true)
#  |-- emb_258: float (nullable = true)
#  |-- emb_259: float (nullable = true)
#  |-- emb_260: float (nullable = true)
#  |-- emb_261: float (nullable = true)
#  |-- emb_262: float (nullable = true)
#  |-- emb_263: float (nullable = true)
#  |-- emb_264: float (nullable = true)
#  |-- emb_265: float (nullable = true)
#  |-- emb_266: float (nullable = true)
#  |-- emb_267: float (nullable = true)
#  |-- emb_268: float (nullable = true)
#  |-- emb_269: float (nullable = true)
#  |-- emb_270: float (nullable = true)
#  |-- emb_271: float (nullable = true)
#  |-- emb_272: float (nullable = true)
#  |-- emb_273: float (nullable = true)
#  |-- emb_274: float (nullable = true)
#  |-- emb_275: float (nullable = true)
#  |-- emb_276: float (nullable = true)
#  |-- emb_277: float (nullable = true)
#  |-- emb_278: float (nullable = true)
#  |-- emb_279: float (nullable = true)
#  |-- emb_280: float (nullable = true)
#  |-- emb_281: float (nullable = true)
#  |-- emb_282: float (nullable = true)
#  |-- emb_283: float (nullable = true)
#  |-- emb_284: float (nullable = true)
#  |-- emb_285: float (nullable = true)
#  |-- emb_286: float (nullable = true)
#  |-- emb_287: float (nullable = true)
#  |-- emb_288: float (nullable = true)
#  |-- emb_289: float (nullable = true)
#  |-- emb_290: float (nullable = true)
#  |-- emb_291: float (nullable = true)
#  |-- emb_292: float (nullable = true)
#  |-- emb_293: float (nullable = true)
#  |-- emb_294: float (nullable = true)
#  |-- emb_295: float (nullable = true)
#  |-- emb_296: float (nullable = true)
#  |-- emb_297: float (nullable = true)
#  |-- emb_298: float (nullable = true)
#  |-- emb_299: float (nullable = true)
#  |-- emb_300: float (nullable = true)
#  |-- emb_301: float (nullable = true)
#  |-- emb_302: float (nullable = true)
#  |-- emb_303: float (nullable = true)
#  |-- emb_304: float (nullable = true)
#  |-- emb_305: float (nullable = true)
#  |-- emb_306: float (nullable = true)
#  |-- emb_307: float (nullable = true)
#  |-- emb_308: float (nullable = true)
#  |-- emb_309: float (nullable = true)
#  |-- emb_310: float (nullable = true)
#  |-- emb_311: float (nullable = true)
#  |-- emb_312: float (nullable = true)
#  |-- emb_313: float (nullable = true)
#  |-- emb_314: float (nullable = true)
#  |-- emb_315: float (nullable = true)
#  |-- emb_316: float (nullable = true)
#  |-- emb_317: float (nullable = true)
#  |-- emb_318: float (nullable = true)
#  |-- emb_319: float (nullable = true)
#  |-- emb_320: float (nullable = true)
#  |-- emb_321: float (nullable = true)
#  |-- emb_322: float (nullable = true)
#  |-- emb_323: float (nullable = true)
#  |-- emb_324: float (nullable = true)
#  |-- emb_325: float (nullable = true)
#  |-- emb_326: float (nullable = true)
#  |-- emb_327: float (nullable = true)
#  |-- emb_328: float (nullable = true)
#  |-- emb_329: float (nullable = true)
#  |-- emb_330: float (nullable = true)
#  |-- emb_331: float (nullable = true)
#  |-- emb_332: float (nullable = true)
#  |-- emb_333: float (nullable = true)
#  |-- emb_334: float (nullable = true)
#  |-- emb_335: float (nullable = true)
#  |-- emb_336: float (nullable = true)
#  |-- emb_337: float (nullable = true)
#  |-- emb_338: float (nullable = true)
#  |-- emb_339: float (nullable = true)
#  |-- emb_340: float (nullable = true)
#  |-- emb_341: float (nullable = true)
#  |-- emb_342: float (nullable = true)
#  |-- emb_343: float (nullable = true)
#  |-- emb_344: float (nullable = true)
#  |-- emb_345: float (nullable = true)
#  |-- emb_346: float (nullable = true)
#  |-- emb_347: float (nullable = true)
#  |-- emb_348: float (nullable = true)
#  |-- emb_349: float (nullable = true)
#  |-- emb_350: float (nullable = true)
#  |-- emb_351: float (nullable = true)
#  |-- emb_352: float (nullable = true)
#  |-- emb_353: float (nullable = true)
#  |-- emb_354: float (nullable = true)
#  |-- emb_355: float (nullable = true)
#  |-- emb_356: float (nullable = true)
#  |-- emb_357: float (nullable = true)
#  |-- emb_358: float (nullable = true)
#  |-- emb_359: float (nullable = true)
#  |-- emb_360: float (nullable = true)
#  |-- emb_361: float (nullable = true)
#  |-- emb_362: float (nullable = true)
#  |-- emb_363: float (nullable = true)
#  |-- emb_364: float (nullable = true)
#  |-- emb_365: float (nullable = true)
#  |-- emb_366: float (nullable = true)
#  |-- emb_367: float (nullable = true)
#  |-- emb_368: float (nullable = true)
#  |-- emb_369: float (nullable = true)
#  |-- emb_370: float (nullable = true)
#  |-- emb_371: float (nullable = true)
#  |-- emb_372: float (nullable = true)
#  |-- emb_373: float (nullable = true)
#  |-- emb_374: float (nullable = true)
#  |-- emb_375: float (nullable = true)
#  |-- emb_376: float (nullable = true)
#  |-- emb_377: float (nullable = true)
#  |-- emb_378: float (nullable = true)
#  |-- emb_379: float (nullable = true)
#  |-- emb_380: float (nullable = true)
#  |-- emb_381: float (nullable = true)
#  |-- emb_382: float (nullable = true)
#  |-- emb_383: float (nullable = true)
#  |-- pca_0: float (nullable = true)
#  |-- pca_1: float (nullable = true)
#  |-- pca_2: float (nullable = true)
#  |-- pca_3: float (nullable = true)
#  |-- pca_4: float (nullable = true)
#  |-- pca_5: float (nullable = true)
#  |-- pca_6: float (nullable = true)
#  |-- pca_7: float (nullable = true)
#  |-- pca_8: float (nullable = true)
#  |-- pca_9: float (nullable = true)
#  |-- pca_10: float (nullable = true)
#  |-- pca_11: float (nullable = true)
#  |-- pca_12: float (nullable = true)
#  |-- pca_13: float (nullable = true)
#  |-- pca_14: float (nullable = true)
#  |-- pca_15: float (nullable = true)
#  |-- pca_16: float (nullable = true)
#  |-- pca_17: float (nullable = true)
#  |-- pca_18: float (nullable = true)
#  |-- pca_19: float (nullable = true)
#  |-- pca_20: float (nullable = true)
#  |-- pca_21: float (nullable = true)
#  |-- pca_22: float (nullable = true)
#  |-- pca_23: float (nullable = true)
#  |-- pca_24: float (nullable = true)
#  |-- pca_25: float (nullable = true)
#  |-- pca_26: float (nullable = true)
#  |-- pca_27: float (nullable = true)
#  |-- pca_28: float (nullable = true)
#  |-- pca_29: float (nullable = true)
#  |-- pca_30: float (nullable = true)
#  |-- pca_31: float (nullable = true)
#  |-- pca_32: float (nullable = true)
#  |-- pca_33: float (nullable = true)
#  |-- pca_34: float (nullable = true)
#  |-- pca_35: float (nullable = true)
#  |-- pca_36: float (nullable = true)
#  |-- pca_37: float (nullable = true)
#  |-- pca_38: float (nullable = true)
#  |-- pca_39: float (nullable = true)
#  |-- pca_40: float (nullable = true)
#  |-- pca_41: float (nullable = true)
#  |-- pca_42: float (nullable = true)
#  |-- pca_43: float (nullable = true)
#  |-- pca_44: float (nullable = true)
#  |-- pca_45: float (nullable = true)
#  |-- pca_46: float (nullable = true)
#  |-- pca_47: float (nullable = true)
#  |-- pca_48: float (nullable = true)
#  |-- pca_49: float (nullable = true)
#  |-- len_chars_gold: long (nullable = true)
#  |-- num_words: long (nullable = true)
#  |-- avg_word_len: double (nullable = true)
#  |-- lm_pos: long (nullable = true)
#  |-- lm_neg: long (nullable = true)
#  |-- lm_unc: long (nullable = true)
#  |-- lm_lit: long (nullable = true)
#  |-- lm_con: long (nullable = true)
#  |-- ner_org: long (nullable = true)
#  |-- ner_gpe: long (nullable = true)
#  |-- ner_person: long (nullable = true)
#  |-- ner_money: long (nullable = true)
#  |-- macro_final: integer (nullable = true)
#  |-- microcluster: integer (nullable = true)
#  |-- thematic_cluster: integer (nullable = true)
# [Stage 35:==============================================>          (9 + 2) / 11]
# Start date: 2016-01-01
# End date: 2020-04-01

# %% [markdown]
# ### Curse of Dimensionality
# With only **~1024 trading days**, adding too many themes — plus sentiment, activity, and lag features for each — makes the feature space **explode**.
# To avoid overfitting and keep the system universal across tickers, we retain only broad, economically meaningful themes.
#
# | Theme | Why It Stays (Universal Economic Impact) |
# |-------|-------------------------------------------|
# | **1. Corporate Earnings & Financial Performance** | Earnings season drives broad sentiment; aggregate corporate health affects indices. |
# | **2. Financial Markets & Trading** | Captures liquidity, flows, and market-wide sentiment. Relevant to every ticker. |
# | **3. Macroeconomic Trends & Outlook** | Inflation, growth, and interest rates drive systematic returns across all assets. |
# | **4. Energy & Commodities Markets** | Oil, gas, and metals impact inflation, supply chains, and sector costs. |
# | **5. Tech Industry & Innovation** | Tech dominates global market cap and risk appetite in the modern era. |
# | **6. International Trade & Relations** | Tariffs, supply chain shocks, and trade tensions affect most equities globally. |
# | **7. Global Geopolitics & Security** | Conflicts, sanctions, and geopolitical risk feed directly into volatility and returns. |
#
#
# ### Columns Kept for Daily Aggregation
# To keep the feature space compact and statistically reliable (~1024 trading days), we retain only columns that contribute meaningful, broad-impact market signals.
# All embedding vectors, PCA dimensions, raw text, and metadata fields are dropped.
#
# | Column / Group | Example Columns | Why We Keep It |
# |----------------|-----------------|----------------|
# | **Date** | `date` → `date_key` | Needed for grouping news into daily aggregates. |
# | **Theme Labels** | `thematic_cluster` | Core explanatory variable: theme counts + theme shocks. |
# | **Lexicon Sentiment** | `lm_pos`, `lm_neg`, `lm_unc`, `lm_lit`, `lm_con` | Captures tone, uncertainty, and sentiment widely shown to influence market returns. |
# | **Entity Mentions** | `ner_org`, `ner_gpe`, `ner_person`, `ner_money` | High-level indicators of economic, geopolitical, or corporate focus in the news flow. |
# | **Text Complexity Metrics** | `len_text`, `num_words`, `avg_word_len` | Cheap proxies for article depth, often correlated with event severity or informational richness. |
# | **Identifiers** | `url` | Only used for joins and diagnostics; not part of modelling. |
#
# ### Columns Dropped
# All high-dimensional or non-economic fields are removed to avoid exploding feature space:
# - **Embeddings:** `emb_0`–`emb_383`
# - **PCA vectors:** `pca_0`–`pca_49`
# - **Raw Text:** `text`
# - **Author / publication metadata:** `author`, `publication`, `source_file`
# - **Silver ingestion timestamps**
# - **Mixed / noisy theme clusters**

# %%
from pyspark.sql.functions import to_date

relevant_cols = [
    "url", "date", "thematic_cluster",
    "lm_pos", "lm_neg", "lm_unc", "lm_lit", "lm_con",
    "ner_org", "ner_gpe", "ner_person",
    "len_text", "num_words", "avg_word_len"
]

df_slim = df.select(*relevant_cols)
df_slim = df_slim.withColumn("date_key", to_date("date"))

relevant_thematic_clusters = [1, 2, 3, 4, 7, 11, 12]

df_slim = df_slim.filter(df_slim.thematic_cluster.isin(relevant_thematic_clusters))

# %%
from pyspark.sql.functions import count, sum as Fsum

# 1. Daily article counts per theme
df_theme_daily = (
    df_slim
        .groupBy("date_key", "thematic_cluster")
        .agg(count("*").alias("count_articles"))
)

df_theme_pivot = (
    df_theme_daily
        .groupBy("date_key")
        .pivot("thematic_cluster")
        .agg(Fsum("count_articles"))
        .na.fill(0)
)

# 2. Sentiment + NER + text metrics per date × theme
df_theme_extra = (
    df_slim
        .groupBy("date_key", "thematic_cluster")
        .agg(
            Fsum("lm_pos").alias("pos_sum"),
            Fsum("lm_neg").alias("neg_sum"),
            Fsum("lm_unc").alias("unc_sum"),
            Fsum("ner_org").alias("org_sum"),
            Fsum("ner_gpe").alias("gpe_sum"),
            Fsum("ner_person").alias("person_sum"),
            Fsum("len_text").alias("total_text_len"),
            Fsum("num_words").alias("total_words"),
        )
)

df_theme_extra_pivot = (
    df_theme_extra
        .groupBy("date_key")
        .pivot("thematic_cluster")
        .agg(
            Fsum("pos_sum").alias("pos_sum"),
            Fsum("neg_sum").alias("neg_sum"),
            Fsum("unc_sum").alias("unc_sum"),
            Fsum("org_sum").alias("org_sum"),
            Fsum("gpe_sum").alias("gpe_sum"),
            Fsum("person_sum").alias("person_sum"),
            Fsum("total_text_len").alias("total_text_len"),
            Fsum("total_words").alias("total_words")
        )
)

# 3. Rename columns based on chosen 1-word theme labels
theme_map = {
    "1": "earnings",
    "2": "markets",
    "3": "macro",
    "4": "energy",
    "7": "tech",
    "11": "trade",
    "12": "geopol"
}

for old, new in theme_map.items():
    for metric in ["pos_sum", "neg_sum", "unc_sum", "org_sum",
                   "gpe_sum", "person_sum", "total_text_len", "total_words"]:
        old_col = f"{old}_{metric}"
        new_col = f"{new}_{metric}"
        if old_col in df_theme_extra_pivot.columns:
            df_theme_extra_pivot = df_theme_extra_pivot.withColumnRenamed(old_col, new_col)

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# ---- 4. Merge article-count pivot and sentiment/NER/words pivot ----

df_daily = (
    df_theme_pivot
        .join(df_theme_extra_pivot, on="date_key", how="inner")
        .orderBy("date_key")
)

from pyspark.sql import functions as F
from pyspark.sql.window import Window

# List of themes
themes = ["earnings", "markets", "macro", "energy", "tech", "trade", "geopol"]

# ---- 1. Compute total words across ALL themes per day ----

total_words_expr = sum(F.col(f"{t}_total_words") for t in themes)

df_daily = df_daily.withColumn("allthemes_total_words", total_words_expr)

# ---- 2. Compute SHARE OF NEWS for each theme ----

for theme in themes:
    df_daily = df_daily.withColumn(
        f"{theme}_activity_share",
        F.col(f"{theme}_total_words") / (F.col("allthemes_total_words") + F.lit(1))
    )

# ---- 3. Rolling window for z-scores ----

w7 = Window.orderBy("date_key").rowsBetween(-7, -1)

# ---- 4. Rolling Z-score of activity share ----

for theme in themes:
    base = f"{theme}_activity_share"
    zname = f"{theme}_activity_share_z7"

    df_daily = df_daily.withColumn(
        zname,
        (F.col(base) - F.avg(base).over(w7)) /
        (F.stddev(base).over(w7) + F.lit(1))
    )

# ---- 7. Sentiment balance, sentiment intensity, uncertainty ratio ----

for theme in themes:
    
    pos = f"{theme}_pos_sum"
    neg = f"{theme}_neg_sum"
    unc = f"{theme}_unc_sum"
    words = f"{theme}_total_words"

    # Sentiment balance: (pos - neg) / (pos + neg + 1)
    df_daily = df_daily.withColumn(
        f"{theme}_sentiment_balance",
        (F.col(pos) - F.col(neg)) / (F.col(pos) + F.col(neg) + F.lit(1))
    )

    # Sentiment intensity: |pos - neg|
    df_daily = df_daily.withColumn(
        f"{theme}_sentiment_intensity",
        F.abs(F.col(pos) - F.col(neg))
    )

df_daily.show(10, truncate=False)
# Out:
# 25/12/08 18:40:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:05 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:13 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:40:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +----------+---+---+---+---+---+---+---+----------------+----------------+----------------+----------------+----------------+-------------------+-----------------------+--------------------+---------------+---------------+---------------+---------------+---------------+------------------+----------------------+-------------------+-------------+-------------+-------------+-------------+-------------+----------------+--------------------+-----------------+--------------+--------------+--------------+--------------+--------------+-----------------+---------------------+------------------+------------+------------+------------+------------+------------+---------------+-------------------+----------------+-------------+-------------+-------------+-------------+-------------+----------------+--------------------+-----------------+--------------+--------------+--------------+--------------+--------------+-----------------+---------------------+------------------+---------------------+-----------------------+----------------------+--------------------+---------------------+--------------------+--------------------+---------------------+--------------------------+-------------------------+-----------------------+------------------------+----------------------+-----------------------+------------------------+--------------------------+----------------------------+-------------------------+---------------------------+-----------------------+-------------------------+------------------------+--------------------------+----------------------+------------------------+-----------------------+-------------------------+------------------------+--------------------------+
# |date_key  |1  |2  |3  |4  |7  |11 |12 |earnings_pos_sum|earnings_neg_sum|earnings_unc_sum|earnings_org_sum|earnings_gpe_sum|earnings_person_sum|earnings_total_text_len|earnings_total_words|markets_pos_sum|markets_neg_sum|markets_unc_sum|markets_org_sum|markets_gpe_sum|markets_person_sum|markets_total_text_len|markets_total_words|macro_pos_sum|macro_neg_sum|macro_unc_sum|macro_org_sum|macro_gpe_sum|macro_person_sum|macro_total_text_len|macro_total_words|energy_pos_sum|energy_neg_sum|energy_unc_sum|energy_org_sum|energy_gpe_sum|energy_person_sum|energy_total_text_len|energy_total_words|tech_pos_sum|tech_neg_sum|tech_unc_sum|tech_org_sum|tech_gpe_sum|tech_person_sum|tech_total_text_len|tech_total_words|trade_pos_sum|trade_neg_sum|trade_unc_sum|trade_org_sum|trade_gpe_sum|trade_person_sum|trade_total_text_len|trade_total_words|geopol_pos_sum|geopol_neg_sum|geopol_unc_sum|geopol_org_sum|geopol_gpe_sum|geopol_person_sum|geopol_total_text_len|geopol_total_words|allthemes_total_words|earnings_activity_share|markets_activity_share|macro_activity_share|energy_activity_share|tech_activity_share |trade_activity_share|geopol_activity_share|earnings_activity_share_z7|markets_activity_share_z7|macro_activity_share_z7|energy_activity_share_z7|tech_activity_share_z7|trade_activity_share_z7|geopol_activity_share_z7|earnings_sentiment_balance|earnings_sentiment_intensity|markets_sentiment_balance|markets_sentiment_intensity|macro_sentiment_balance|macro_sentiment_intensity|energy_sentiment_balance|energy_sentiment_intensity|tech_sentiment_balance|tech_sentiment_intensity|trade_sentiment_balance|trade_sentiment_intensity|geopol_sentiment_balance|geopol_sentiment_intensity|
8361              |41103                |0.03481413001167769    |0.19285227715064227   |0.20851985208252238 |0.05773160762942779  |0.1387942779291553  |0.1638526664071623  |0.2034108602569093   |0.0032752748013177508     |-0.03421130328932273     |-0.006331174525305171  |0.023357696270354934    |-0.008797887188048605 |0.026674378221855255   |-0.0024553810730773896  |0.038461538461538464      |1                           |-0.3761904761904762      |79                         |-0.42777777777777776   |77                       |-0.6865671641791045     |46                        |0.08421052631578947   |8                       |-0.5379310344827586    |78                       |-0.5956521739130435     |137                       |
# +----------+---+---+---+---+---+---+---+----------------+----------------+----------------+----------------+----------------+-------------------+-----------------------+--------------------+---------------+---------------+---------------+---------------+---------------+------------------+----------------------+-------------------+-------------+-------------+-------------+-------------+-------------+----------------+--------------------+-----------------+--------------+--------------+--------------+--------------+--------------+-----------------+---------------------+------------------+------------+------------+------------+------------+------------+---------------+-------------------+----------------+-------------+-------------+-------------+-------------+-------------+----------------+--------------------+-----------------+--------------+--------------+--------------+--------------+--------------+-----------------+---------------------+------------------+---------------------+-----------------------+----------------------+--------------------+---------------------+--------------------+--------------------+---------------------+--------------------------+-------------------------+-----------------------+------------------------+----------------------+-----------------------+------------------------+--------------------------+----------------------------+-------------------------+---------------------------+-----------------------+-------------------------+------------------------+--------------------------+----------------------+------------------------+-----------------------+-------------------------+------------------------+--------------------------+
# only showing top 10 rows

# %%
#uncertainty ratio, sentiment volatility, uncertainty z-score
from pyspark.sql import functions as F
from pyspark.sql.window import Window

w7 = Window.orderBy("date_key").rowsBetween(-7, -1)

for theme in themes:
    unc = f"{theme}_unc_sum"
    words = f"{theme}_total_words"
    bal = f"{theme}_sentiment_balance"
    
    # --- 1. Normalised uncertainty ---
    df_daily = df_daily.withColumn(
        f"{theme}_uncertainty_ratio",
        F.col(unc) / (F.col(words) + F.lit(1))
    )
    
    # --- 2. Sentiment volatility (rolling 7d std) ---
    df_daily = df_daily.withColumn(
        f"{theme}_sentiment_volatility",
        F.stddev(bal).over(w7)
    )
    
    # --- 3. Surprise uncertainty (rolling z-score) ---
    df_daily = df_daily.withColumn(
        f"{theme}_uncertainty_z7",
        (F.col(f"{theme}_uncertainty_ratio")
         - F.avg(f"{theme}_uncertainty_ratio").over(w7))
        /
        (F.stddev(f"{theme}_uncertainty_ratio").over(w7) + F.lit(1))
    )

# %%
df_daily.printSchema()
# Out:
# root
#  |-- date_key: date (nullable = true)
#  |-- 1: long (nullable = true)
#  |-- 2: long (nullable = true)
#  |-- 3: long (nullable = true)
#  |-- 4: long (nullable = true)
#  |-- 7: long (nullable = true)
#  |-- 11: long (nullable = true)
#  |-- 12: long (nullable = true)
#  |-- earnings_pos_sum: long (nullable = true)
#  |-- earnings_neg_sum: long (nullable = true)
#  |-- earnings_unc_sum: long (nullable = true)
#  |-- earnings_org_sum: long (nullable = true)
#  |-- earnings_gpe_sum: long (nullable = true)
#  |-- earnings_person_sum: long (nullable = true)
#  |-- earnings_total_text_len: long (nullable = true)
#  |-- earnings_total_words: long (nullable = true)
#  |-- markets_pos_sum: long (nullable = true)
#  |-- markets_neg_sum: long (nullable = true)
#  |-- markets_unc_sum: long (nullable = true)
#  |-- markets_org_sum: long (nullable = true)
#  |-- markets_gpe_sum: long (nullable = true)
#  |-- markets_person_sum: long (nullable = true)
#  |-- markets_total_text_len: long (nullable = true)
#  |-- markets_total_words: long (nullable = true)
#  |-- macro_pos_sum: long (nullable = true)
#  |-- macro_neg_sum: long (nullable = true)
#  |-- macro_unc_sum: long (nullable = true)
#  |-- macro_org_sum: long (nullable = true)
#  |-- macro_gpe_sum: long (nullable = true)
#  |-- macro_person_sum: long (nullable = true)
#  |-- macro_total_text_len: long (nullable = true)
#  |-- macro_total_words: long (nullable = true)
#  |-- energy_pos_sum: long (nullable = true)
#  |-- energy_neg_sum: long (nullable = true)
#  |-- energy_unc_sum: long (nullable = true)
#  |-- energy_org_sum: long (nullable = true)
#  |-- energy_gpe_sum: long (nullable = true)
#  |-- energy_person_sum: long (nullable = true)
#  |-- energy_total_text_len: long (nullable = true)
#  |-- energy_total_words: long (nullable = true)
#  |-- tech_pos_sum: long (nullable = true)
#  |-- tech_neg_sum: long (nullable = true)
#  |-- tech_unc_sum: long (nullable = true)
#  |-- tech_org_sum: long (nullable = true)
#  |-- tech_gpe_sum: long (nullable = true)
#  |-- tech_person_sum: long (nullable = true)
#  |-- tech_total_text_len: long (nullable = true)
#  |-- tech_total_words: long (nullable = true)
#  |-- trade_pos_sum: long (nullable = true)
#  |-- trade_neg_sum: long (nullable = true)
#  |-- trade_unc_sum: long (nullable = true)
#  |-- trade_org_sum: long (nullable = true)
#  |-- trade_gpe_sum: long (nullable = true)
#  |-- trade_person_sum: long (nullable = true)
#  |-- trade_total_text_len: long (nullable = true)
#  |-- trade_total_words: long (nullable = true)
#  |-- geopol_pos_sum: long (nullable = true)
#  |-- geopol_neg_sum: long (nullable = true)
#  |-- geopol_unc_sum: long (nullable = true)
#  |-- geopol_org_sum: long (nullable = true)
#  |-- geopol_gpe_sum: long (nullable = true)
#  |-- geopol_person_sum: long (nullable = true)
#  |-- geopol_total_text_len: long (nullable = true)
#  |-- geopol_total_words: long (nullable = true)
#  |-- allthemes_total_words: long (nullable = true)
#  |-- earnings_activity_share: double (nullable = true)
#  |-- markets_activity_share: double (nullable = true)
#  |-- macro_activity_share: double (nullable = true)
#  |-- energy_activity_share: double (nullable = true)
#  |-- tech_activity_share: double (nullable = true)
#  |-- trade_activity_share: double (nullable = true)
#  |-- geopol_activity_share: double (nullable = true)
#  |-- earnings_activity_share_z7: double (nullable = true)
#  |-- markets_activity_share_z7: double (nullable = true)
#  |-- macro_activity_share_z7: double (nullable = true)
#  |-- energy_activity_share_z7: double (nullable = true)
#  |-- tech_activity_share_z7: double (nullable = true)
#  |-- trade_activity_share_z7: double (nullable = true)
#  |-- geopol_activity_share_z7: double (nullable = true)
#  |-- earnings_sentiment_balance: double (nullable = true)
#  |-- earnings_sentiment_intensity: long (nullable = true)
#  |-- markets_sentiment_balance: double (nullable = true)
#  |-- markets_sentiment_intensity: long (nullable = true)
#  |-- macro_sentiment_balance: double (nullable = true)
#  |-- macro_sentiment_intensity: long (nullable = true)
#  |-- energy_sentiment_balance: double (nullable = true)
#  |-- energy_sentiment_intensity: long (nullable = true)
#  |-- tech_sentiment_balance: double (nullable = true)
#  |-- tech_sentiment_intensity: long (nullable = true)
#  |-- trade_sentiment_balance: double (nullable = true)
#  |-- trade_sentiment_intensity: long (nullable = true)
#  |-- geopol_sentiment_balance: double (nullable = true)
#  |-- geopol_sentiment_intensity: long (nullable = true)
#  |-- earnings_uncertainty_ratio: double (nullable = true)
#  |-- earnings_sentiment_volatility: double (nullable = true)
#  |-- earnings_uncertainty_z7: double (nullable = true)
#  |-- markets_uncertainty_ratio: double (nullable = true)
#  |-- markets_sentiment_volatility: double (nullable = true)
#  |-- markets_uncertainty_z7: double (nullable = true)
#  |-- macro_uncertainty_ratio: double (nullable = true)
#  |-- macro_sentiment_volatility: double (nullable = true)
#  |-- macro_uncertainty_z7: double (nullable = true)
#  |-- energy_uncertainty_ratio: double (nullable = true)
#  |-- energy_sentiment_volatility: double (nullable = true)
#  |-- energy_uncertainty_z7: double (nullable = true)
#  |-- tech_uncertainty_ratio: double (nullable = true)
#  |-- tech_sentiment_volatility: double (nullable = true)
#  |-- tech_uncertainty_z7: double (nullable = true)
#  |-- trade_uncertainty_ratio: double (nullable = true)
#  |-- trade_sentiment_volatility: double (nullable = true)
#  |-- trade_uncertainty_z7: double (nullable = true)
#  |-- geopol_uncertainty_ratio: double (nullable = true)
#  |-- geopol_sentiment_volatility: double (nullable = true)
#  |-- geopol_uncertainty_z7: double (nullable = true)

# %%
#to pd to csv
pdf = df_daily.toPandas()
out_path = ROOT / "modelling" / "features"
out_path.mkdir(parents=True, exist_ok=True)
pdf.to_csv(out_path / "daily_features.csv", index=False)
print("Saved:", out_path / "daily_features.csv")
# Out:
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:33 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/08 18:42:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# Saved: /home/david/School/CapStone/modelling/features/daily_features.csv
# 25/12/09 13:53:47 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 47588860 ms exceeds timeout 120000 ms
# 25/12/09 13:53:47 WARN SparkContext: Killing executors is not supported by current scheduler.
# 25/12/09 13:53:48 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.16.0.186:37675
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/12/09 13:53:48 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:572)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:358)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.16.0.186:37675
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/12/09 13:53:58 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.16.0.186:37675
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# ...
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/12/09 14:03:38 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:572)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:358)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.16.0.186:37675
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/12/09 14:03:38 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.16.0.186:37675
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/12/09 14:03:38 ERROR Executor: Exit as unable to send heartbeats to driver more than 60 times
